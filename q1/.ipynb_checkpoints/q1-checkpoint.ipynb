# %%
import csv
import matplotlib.pyplot as plt

#dfsfsfs

def main():
    f= open('all_temp_month.csv','r',encoding='cp949')
    data = csv.reader(f)
    header = next(data)
    
    plt.rc('font',family = 'Malgun Gothic')
    plt.rcParams['axes.unicode_minus']=False
    #타이틀
    plt.title('2022년 1월 ~ 12월의 월평균 기온')
    plt.xlabel('월')
    plt.ylabel('온도')
    
    result = []
    xGraph=[]
    for row in data:
        row[0] = row[0].split('-')[1]
        if row[2] != '':
            result.append(float(row[2]))
            xGraph.append(int(row[0]))
            
    f2= open('seoul_temp_moth.csv','r',encoding='cp949')
    data2 = csv.reader(f2)
    header2 = next(data2)
    result2 = []
    xGraph2=[]
    for row2 in data2:
        row2[0] = row2[0].split('-')[1]
        if row2[2] != '':
            result2.append(float(row2[2]))
            xGraph2.append(int(row2[0]))
    
    f3 = open('busan_month.csv','r',encoding='cp949')
    data3 = csv.reader(f3)
    header3 = next(data3)
    result3 = []
    xGraph3=[]
    for row3 in data3:
        row3[0] = row3[0].split('-')[1]
        if row3[2] != '':
            result3.append(float(row3[2]))
            xGraph3.append(int(row3[0]))
            
    f4 = open('dejon_temp_month.csv','r',encoding='cp949')
    data4 = csv.reader(f4)
    header4 = next(data4)
    result4 = []
    xGraph4=[]
    for row4 in data4:
        row4[0] = row4[0].split('-')[1]
        if row4[2] != '':
            result4.append(float(row4[2]))
            xGraph4.append(int(row4[0]))
    
    f5 = open('jeju_month.csv','r',encoding='cp949')
    data5 = csv.reader(f5)
    header5 = next(data5)
    result5 = []
    xGraph5=[]
    for row5 in data5:
        row5[0] = row5[0].split('-')[1]
        if row5[2] != '':
            result5.append(float(row5[2]))
            xGraph5.append(int(row5[0]))
    
    
    plt.plot(xGraph,result,label='전국')
    plt.plot(xGraph2,result2,label='서울')
    plt.plot(xGraph3,result3,label='부산')
    plt.plot(xGraph4,result4,label='대전')
    plt.plot(xGraph5,result5,label='제주')



    plt.legend()
    plt.show()
    f.close()
    f2.close()
    f3.close()

if __name__ == "__main__":
    main()
